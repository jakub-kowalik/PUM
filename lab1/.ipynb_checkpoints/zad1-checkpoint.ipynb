# %%
from sklearn import datasets, metrics, linear_model
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import PolynomialFeatures
import matplotlib.pyplot as plt
import numpy as np
import scipy
import time
import pandas as pd
loop = 100
seed = 244823
samples = 2425
noise = 16

# %%
x, y = datasets.make_regression(n_features=1, random_state=seed, n_samples=samples, noise=noise)
poly = PolynomialFeatures(1)
x = poly.fit_transform(x)
xtrain, xtest, ytrain, ytest = train_test_split(x,y, test_size=0.2, train_size=0.2, random_state=seed)

# %% [markdown]
# # Metoda analityczna ![image.png](attachment:image.png)

# %%
xt = np.transpose(xtrain)
xtx=np.matmul(xt, xtrain)
xtxinv = np.linalg.inv(xtx)
xty = np.matmul(xt, ytrain)
theta = np.matmul(xtxinv, xty)

# %%
start_time = time.time()
for i in range(loop):
    answeranal = np.matmul(np.linalg.inv(np.matmul(np.transpose(xtrain), xtrain)), np.matmul(np. transpose(xtrain), ytrain))
end_time_anal = (time.time() - start_time)/loop
print(f'Czas całkowity 100 wykonań metody analitycznej wynosi {round((end_time_anal*1000),5)} ms')
# Out:
# Czas całkowity 100 wykonań metody analitycznej wynosi 0.0 ms

# %% [markdown]
# # Metoda numeryczna ![image.png](attachment:image.png)

# %%
def numeric(w, x, y):
    xt_times_theta = np.matmul(xtrain, w)
    xt_times_theta_minus_y = np.subtract(y, xt_times_theta)
    transposed = xt_times_theta_minus_y.transpose()
    final = np.matmul(xt_times_theta_minus_y, transposed)
    return final / len(x)

# %%
start_time = time.time()
for i in range(loop):
    answernum = scipy.optimize.minimize(numeric,[1,1], args=(xtrain, ytrain), method="Powell")
end_time_num = (time.time() - start_time)/loop
print(f'Czas całkowity 100 wykonań metody numerycznej wynosi {round((end_time_num*1000),5)} ms')
# Out:
# Czas całkowity 100 wykonań metody numerycznej wynosi 2.2016 ms

# %%
ynum1 = answernum.x[1]*-3+answernum.x[0]
ynum2 = answernum.x[1]*3+answernum.x[0]
yanal1 = theta[1]*-3+theta[0]
yanal2 = theta[1]*3+theta[0]

plt.scatter(np.delete(xtrain, 0,1), ytrain, alpha=0.2, color='blue', label = 'Train data', marker='x')
plt.scatter(np.delete(xtest, 0,1), ytest, alpha=0.2, color='yellow', label = 'Test data', marker='x')
plt.plot([-3,3],[ynum1,ynum2], label='Numeric fit', color='blue')
plt.plot([-3,3],[yanal1,yanal2], label='Analytic fit', color='yellow')
plt.legend()
plt.show()

# %%
xtest = np.delete(xtest,0,1)
xtest=np.ndarray.tolist(xtest)
ytest=np.ndarray.tolist(ytest)

# %%
ypredicted_anal = []
ypredicted_num = []
xtestlepszy =[]
for i in xtest:
    xtestlepszy += [i][0]
for i in xtestlepszy:
    ypredicted_anal.append(i*theta[1]+theta[0])
for i in xtestlepszy:
    ypredicted_num.append(i*answernum.x[1]+answernum.x[0])
mseanal = round(np.square(np.subtract(ytest,ypredicted_anal)).mean())
msenum = round(np.square(np.subtract(ytest,ypredicted_num)).mean())
print(f'Średni błąd kwadratowy metody analitycznej wynosi {mseanal}')
print(f'Średni błąd kwadratowy metody numerycznej wynosi {msenum}')
# Out:
# Średni błąd kwadratowy metody analitycznej wynosi 231
# Średni błąd kwadratowy metody numerycznej wynosi 231

# %% [markdown]
# # ---------------------------------------------------------------------------------------------------------------

# %% [markdown]
# # Flapped Bird

# %%
flp1 = np.genfromtxt('1.csv', delimiter=',')

xset=np.reshape(flp1[:,0], (len(flp1),1))
yset=np.reshape(flp1[:,1], (len(flp1),1))
xset = (xset - np.min(xset))/np.max(xset)-np.min(xset)

poly9 = PolynomialFeatures(9).fit_transform(xset)
poly21 = PolynomialFeatures(21).fit_transform(xset)
model9 = linear_model.LinearRegression()
model21 = linear_model.LinearRegression()
model9.fit(poly9, yset)
model21.fit(poly21, yset)
ypredicted9 = model9.predict(poly9)
ypredicted21 = model21.predict(poly21)

plt.rcParams['figure.figsize'] = [20, 6]
fig, (ax1, ax2) = plt.subplots(1, 2)
ax1.scatter(xset,yset, alpha = 0.5)
ax2.scatter(xset,yset, alpha = 0.5)
fig.suptitle('Zestaw danych 1')
ax1.plot(xset, ypredicted9, color='r')
ax2.plot(xset, ypredicted21, color='r')
ax1.title.set_text('Polynomial 9')
ax2.title.set_text('Polynomial 21')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Input In [11], in <cell line: 1>()
# ----> 1 flp1 = np.genfromtxt('1.csv', delimiter=',')
#       3 xset=np.reshape(flp1[:,0], (len(flp1),1))
#       4 yset=np.reshape(flp1[:,1], (len(flp1),1))
#
# File ~\anaconda3\envs\PUM\lib\site-packages\numpy\lib\npyio.py:1793, in genfromtxt(fname, dtype, comments, delimiter, skip_header, skip_footer, converters, missing_values, filling_values, usecols, names, excludelist, deletechars, replace_space, autostrip, case_sensitive, defaultfmt, unpack, usemask, loose, invalid_raise, max_rows, encoding, like)
#    1791     fname = os_fspath(fname)
#    1792 if isinstance(fname, str):
# -> 1793     fid = np.lib._datasource.open(fname, 'rt', encoding=encoding)
#    1794     fid_ctx = contextlib.closing(fid)
#    1795 else:
#
# File ~\anaconda3\envs\PUM\lib\site-packages\numpy\lib\_datasource.py:193, in open(path, mode, destpath, encoding, newline)
#     156 """
#     157 Open `path` with `mode` and return the file object.
#     158
#    (...)
#     189
#     190 """
#     192 ds = DataSource(destpath)
# --> 193 return ds.open(path, mode, encoding=encoding, newline=newline)
#
# File ~\anaconda3\envs\PUM\lib\site-packages\numpy\lib\_datasource.py:533, in DataSource.open(self, path, mode, encoding, newline)
#     530     return _file_openers[ext](found, mode=mode,
#     531                               encoding=encoding, newline=newline)
#     532 else:
# --> 533     raise IOError("%s not found." % path)
#
# OSError: 1.csv not found.

# %%
flp2 = np.genfromtxt('2.csv', delimiter=',')
xset=np.reshape(flp2[:,0], (len(flp2),1))
yset=np.reshape(flp2[:,1], (len(flp2),1))
xset = (xset - np.min(xset))/np.max(xset)-np.min(xset)

poly9 = PolynomialFeatures(9).fit_transform(xset)
poly21 = PolynomialFeatures(21).fit_transform(xset)
model9 = linear_model.LinearRegression()
model21 = linear_model.LinearRegression()
model9.fit(poly9, yset)
model21.fit(poly21, yset)
ypredicted9 = model9.predict(poly9)
ypredicted21 = model21.predict(poly21)

plt.rcParams['figure.figsize'] = [20, 6]
fig, (ax1, ax2) = plt.subplots(1, 2)
ax1.scatter(xset,yset, alpha = 0.5)
ax2.scatter(xset,yset, alpha = 0.5)
fig.suptitle('Zestaw danych 2')
ax1.plot(xset, ypredicted9, color='r')
ax2.plot(xset, ypredicted21, color='r')
ax1.title.set_text('Polynomial 9')
ax2.title.set_text('Polynomial 21')
plt.show()

# %%
flp3 = np.genfromtxt('3.csv', delimiter=',')

xset=np.reshape(flp3[:,0], (len(flp3),1))
yset=np.reshape(flp3[:,1], (len(flp3),1))
xset = (xset - np.min(xset))/np.max(xset)-np.min(xset)

poly9 = PolynomialFeatures(9).fit_transform(xset)
poly21 = PolynomialFeatures(21).fit_transform(xset)
model9 = linear_model.LinearRegression()
model21 = linear_model.LinearRegression()
model9.fit(poly9, yset)
model21.fit(poly21, yset)
ypredicted9 = model9.predict(poly9)
ypredicted21 = model21.predict(poly21)

plt.rcParams['figure.figsize'] = [20, 6]
fig, (ax1, ax2) = plt.subplots(1, 2)
ax1.scatter(xset,yset, alpha = 0.5)
ax2.scatter(xset,yset, alpha = 0.5)
fig.suptitle('Zestaw danych 3')
ax1.plot(xset, ypredicted9, color='r')
ax2.plot(xset, ypredicted21, color='r')
ax1.title.set_text('Polynomial 9')
ax2.title.set_text('Polynomial 21')
plt.show()

# %% [markdown]
# # Analityczny flappy

# %%
flp3 = np.genfromtxt('3.csv', delimiter=',')

xset=np.reshape(flp3[:,0], (len(flp3),1))
yset=np.reshape(flp3[:,1], (len(flp3),1))
xset = (xset - np.min(xset))/np.max(xset)-np.min(xset)

xtrain9, xtest9, ytrain9, ytest9 = train_test_split(xset,yset, test_size=0.2, train_size=0.2, random_state=seed)
xtrain21, xtest21, ytrain21, ytest21 = train_test_split(xset,yset, test_size=0.2, train_size=0.2, random_state=seed)


poly9 = PolynomialFeatures(9).fit_transform(xtrain9)
poly21 = PolynomialFeatures(21).fit_transform(xtrain21)

# %%
xt = np.transpose(poly9)
xtx=np.matmul(xt, poly9)
xtxinv = np.linalg.inv(xtx)
xty = np.matmul(xt, ytrain9)
theta9 = np.matmul(xtxinv, xty)

xt = np.transpose(poly21)
xtx=np.matmul(xt, poly21)
xtxinv = np.linalg.inv(xtx)
xty = np.matmul(xt, ytrain21)
theta21 = np.matmul(xtxinv, xty)

# %%
start_time = time.time()
for i in range(loop):
    answeranal = np.matmul(np.linalg.inv(np.matmul(np.transpose(xtrain9), xtrain9)), np.matmul(np.transpose(xtrain9), ytrain9))
end_time_anal = (time.time() - start_time)/loop
print(f'Czas całkowity 100 wykonań metody analitycznej wynosi {round((end_time_anal*1000),5)} ms')

# %%
poly9 = pd.DataFrame(poly9)
poly9 = pd.DataFrame.sort_values(poly9, by=1)
ypredictedtrain9 = np.sum(np.matmul(poly9, theta9), axis=1)
ypredictedtrain21 = np.sum(np.matmul(poly21, theta21), axis=1)

plt.scatter(xtrain9, ytrain9, alpha=0.2, color='blue', label = 'Train data', marker='x')
plt.scatter(xtest9, ytest9, alpha=0.2, color='yellow', label = 'Test data', marker='x')
plt.plot(xtrain9, ypredictedtrain9, label='Polynomial 9', color='blue')
# plt.plot(xtrain21, ypredictedtrain21, label='Polynomial 21', color='yellow')
plt.legend()
plt.show()
